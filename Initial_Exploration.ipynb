# %%
# Modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Podcast_df = pd.read_csv('Data/train.csv')

# %%
Podcast_df
# Out:
#             id      Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0            0   Mystery Matters    Episode 98                     NaN
# 1            1     Joke Junction    Episode 26                  119.80
# 2            2    Study Sessions    Episode 16                   73.90
# 3            3    Digital Digest    Episode 45                   67.17
# 4            4       Mind & Body    Episode 86                  110.51
# ...        ...               ...           ...                     ...
# 749995  749995      Learning Lab    Episode 25                   75.66
# 749996  749996   Business Briefs    Episode 21                   75.75
# 749997  749997  Lifestyle Lounge    Episode 51                   30.98
# 749998  749998       Style Guide    Episode 47                  108.98
# 749999  749999    Sports Central    Episode 99                   24.10
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
Podcast_df.columns
# Out:
# Index(['id', 'Podcast_Name', 'Episode_Title', 'Episode_Length_minutes',
#        'Genre', 'Host_Popularity_percentage', 'Publication_Day',
#        'Publication_Time', 'Guest_Popularity_percentage', 'Number_of_Ads',
#        'Episode_Sentiment', 'Listening_Time_minutes'],
#       dtype='object')

# %%
Podcast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           750000 non-null  int64
#  1   Podcast_Name                 750000 non-null  object
#  2   Episode_Title                750000 non-null  object
#  3   Episode_Length_minutes       662907 non-null  float64
#  4   Genre                        750000 non-null  object
#  5   Host_Popularity_percentage   750000 non-null  float64
#  6   Publication_Day              750000 non-null  object
#  7   Publication_Time             750000 non-null  object
#  8   Guest_Popularity_percentage  603970 non-null  float64
#  9   Number_of_Ads                749999 non-null  float64
#  10  Episode_Sentiment            750000 non-null  object
#  11  Listening_Time_minutes       750000 non-null  float64
# ...

# %%
Podcast_df.describe()
# Out:
#                   id  Episode_Length_minutes  Host_Popularity_percentage  \
# count  750000.000000           662907.000000               750000.000000
# mean   374999.500000               64.504738                   59.859901
# std    216506.495284               32.969603                   22.873098
# min         0.000000                0.000000                    1.300000
# 25%    187499.750000               35.730000                   39.410000
# 50%    374999.500000               63.840000                   60.050000
# 75%    562499.250000               94.070000                   79.530000
# max    749999.000000              325.240000                  119.460000
#
#        Guest_Popularity_percentage  Number_of_Ads  Listening_Time_minutes
# count                603970.000000  749999.000000           750000.000000
# mean                     52.236449       1.348855               45.437406
# std                      28.451241       1.151130               27.138306
# ...

# %%
Podcast_df['Podcast_Name'].value_counts()
# Out:
# Podcast_Name
# Tech Talks             22847
# Sports Weekly          20053
# Funny Folks            19635
# Tech Trends            19549
# Fitness First          19488
# Business Insights      19480
# Style Guide            19364
# Game Day               19272
# Melody Mix             18889
# Criminal Minds         17735
# Finance Focus          17628
# Detective Diaries      17452
# Crime Chronicles       17374
# Athlete's Arena        17327
# Fashion Forward        17280
# Tune Time              17254
# Business Briefs        17012
# Lifestyle Lounge       16661
# True Crime Stories     16373
# Sports Central         16191
# Digital Digest         16171
# Humor Hub              16144
# Mystery Matters        16002
# Comedy Corner          15927
# Joke Junction          15074
# Wellness Wave          15009
# Sport Spot             14778
# Gadget Geek            14770
# Home & Living          14686
# Laugh Line             14673
# Life Lessons           14464
# ...

# %%
Podcast_df['Episode_Sentiment'].value_counts(dropna=False)
# Out:
# Episode_Sentiment
# Neutral     251291
# Negative    250116
# Positive    248593
# Name: count, dtype: int64

# %%
Podcast_df['Number_of_Ads'].value_counts(dropna=False)
# Out:
# Number_of_Ads
# 0.00      217592
# 1.00      214069
# 3.00      160173
# 2.00      158156
# 103.25         2
# 53.37          1
# NaN            1
# 103.91         1
# 103.00         1
# 53.42          1
# 103.75         1
# 12.00          1
# 103.88         1
# Name: count, dtype: int64

# %%
Podcast_df[Podcast_df['Number_of_Ads'] ==103.25]
# Out:
#             id Podcast_Name Episode_Title  Episode_Length_minutes  Genre  \
# 602553  602553  Sound Waves    Episode 53                  112.27  Music
# 672139  672139  Sound Waves    Episode 35                  115.74  Music
#
#         Host_Popularity_percentage Publication_Day Publication_Time  \
# 602553                       28.19         Tuesday          Morning
# 672139                       28.95         Tuesday        Afternoon
#
#         Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 602553                        23.15         103.25           Neutral
# 672139                        23.50         103.25           Neutral
#
#         Listening_Time_minutes
# 602553               103.12686
# 672139               103.12686

# %%
Podcast_df['Genre'].value_counts(dropna=False)
# Out:
# Genre
# Sports        87606
# Technology    86256
# True Crime    85059
# Lifestyle     82461
# Comedy        81453
# Business      80521
# Health        71416
# News          63385
# Music         62743
# Education     49100
# Name: count, dtype: int64

# %%
  Podcast_df['Episode_Length_minutes'].value_counts(dropna=False)
# Out:
# Episode_Length_minutes
# NaN          87093
# 6.600000       925
# 34.400000      617
# 30.690000      576
# 31.680000      533
#              ...
# 14.498053        1
# 8.115479         1
# 93.660301        1
# 98.298620        1
# 62.167294        1
# Name: count, Length: 12269, dtype: int64

# %%
Podcast_Test_df['Episode_Length_minutes'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 Podcast_Test_df['Episode_Length_minutes'].value_counts(dropna=False)
#
# NameError: name 'Podcast_Test_df' is not defined

# %%
Podcast_Test_df = pd.read_csv('Data/test.csv')
Podcast_Test_df

# %%
Podcast_Test_df['Publication_Day'].value_counts(dropna=False)

# %%
Podcast_Test_df['Publication_Time'].value_counts(dropna=False)

# %%
Podcast_df[Podcast_df['Episode_Length_minutes'].isna()]
# Out:
#             id     Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0            0  Mystery Matters    Episode 98                     NaN
# 9            9    Music Matters    Episode 81                     NaN
# 29          29      Health Hour    Episode 38                     NaN
# 43          43      Funny Folks    Episode 93                     NaN
# 49          49      Style Guide    Episode 75                     NaN
# ...        ...              ...           ...                     ...
# 749926  749926  Current Affairs    Episode 48                     NaN
# 749936  749936       Melody Mix     Episode 7                     NaN
# 749943  749943      World Watch    Episode 42                     NaN
# 749954  749954     Life Lessons    Episode 54                     NaN
# 749984  749984         Game Day    Episode 13                     NaN
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
Null_df = Podcast_df[Podcast_df['Episode_Length_minutes'].isna()]

# %%
Null_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87093 entries, 0 to 749984
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           87093 non-null  int64
#  1   Podcast_Name                 87093 non-null  object
#  2   Episode_Title                87093 non-null  object
#  3   Episode_Length_minutes       0 non-null      float64
#  4   Genre                        87093 non-null  object
#  5   Host_Popularity_percentage   87093 non-null  float64
#  6   Publication_Day              87093 non-null  object
#  7   Publication_Time             87093 non-null  object
#  8   Guest_Popularity_percentage  64921 non-null  float64
#  9   Number_of_Ads                87093 non-null  float64
#  10  Episode_Sentiment            87093 non-null  object
#  11  Listening_Time_minutes       87093 non-null  float64
# dtypes: float64(5), int64(1), object(6)
# ...

# %%
notnull_df = Podcast_df[Podcast_df['Episode_Length_minutes'].notna()]
notnull_df
# Out:
#             id      Podcast_Name Episode_Title  Episode_Length_minutes  \
# 1            1     Joke Junction    Episode 26                  119.80
# 2            2    Study Sessions    Episode 16                   73.90
# 3            3    Digital Digest    Episode 45                   67.17
# 4            4       Mind & Body    Episode 86                  110.51
# 5            5     Fitness First    Episode 19                   26.54
# ...        ...               ...           ...                     ...
# 749995  749995      Learning Lab    Episode 25                   75.66
# 749996  749996   Business Briefs    Episode 21                   75.75
# 749997  749997  Lifestyle Lounge    Episode 51                   30.98
# 749998  749998       Style Guide    Episode 47                  108.98
# 749999  749999    Sports Central    Episode 99                   24.10
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %% [markdown]
# # Results
#
# *  750,000 rows in the training and 250,000 in the test.
# *  12 categories, six categorical, six numerical.
# *  linear regression.
# *  around 10% of the category

# %%
len(Podcast_df['Podcast_Name'].value_counts())

# %%
# Study of the length of programs
Prog_Tech_Talks = Podcast_df[Podcast_df['Podcast_Name'] == 'Tech Talks']

# %%
Prog_Tech_Talks
# Out:
#             id Podcast_Name Episode_Title  Episode_Length_minutes       Genre  \
#